# %% [markdown]
# <a href="https://colab.research.google.com/github/thisishasan/cbir_system/blob/main/06_train_auto_encoder_magnification_1_400.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/My Drive/01_information_retrieval'
# !ls
# Out:
# /content/drive/My Drive/01_information_retrieval
# binary_scenario    training_1_100	training_1_200.h5    training_1_40.json
# Notes.gdoc	   training_1_100.h5	training_1_200.json
# original	   training_1_100.json	training_1_40
# subclass_scenario  training_1_200	training_1_40.h5

# %%
import matplotlib
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
import numpy as np
import cv2
import os
import json

# %%
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import Conv2DTranspose
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Reshape
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
import numpy as np

# %%
class ConvAutoEncoder:
    @staticmethod
    def build(width, height, depth, filters=(128,), latent_dim=48):
        input_shape = (height, width, depth)
        channel_dim = -1
        inputs = Input(shape=input_shape)
        x = inputs
        # Encoder layer
        for f in filters:
            x = Conv2D(f, (3, 3), strides=2, padding='same')(x)
            x = LeakyReLU(negative_slope=0.2)(x)
            x = BatchNormalization(axis=channel_dim, name='enc_filter_'+str(f))(x)

        volume_size = K.int_shape(x)
        x = Flatten()(x)
        # Latent layer
        latent = Dense(latent_dim, name="encoded")(x)

        # Decoder layer
        x = Dense(int(np.prod(volume_size[1:])))(latent)
        x = Reshape((volume_size[1], volume_size[2], volume_size[3]))(x)

        # Reverse on decoder
        for f in filters[::-1]:
            x = Conv2DTranspose(f, (3, 3), strides=2, padding='same')(x)
            x = LeakyReLU(negative_slope=0.2)(x)
            x = BatchNormalization(axis=channel_dim, name='dec_filter_'+str(f))(x)

        x = Conv2DTranspose(depth, (3, 3), padding="same")(x)
        outputs = Activation("sigmoid", name="decoded")(x)

        auto_encoder = Model(inputs, outputs, name="auto_encoder")
        return auto_encoder

# %%
def visualize_predictions(_decoded, gt, samples=10):
    outputs = None
    for i in range(0, samples):
        original = (gt[i] * 255).astype("uint8")
        recon = (_decoded[i] * 255).astype("uint8")
        output = np.hstack([original, recon])
        outputs = output if outputs is None else np.vstack([outputs, output])
    return outputs

# %%
EPOCHS = 50
INIT_LR = 1e-3
BS = 32
IMAGE_SIZE = (256, 256)
checkpoint_path = "training_1_400/cp.ckpt.weights.h5"
checkpoint_dir = os.path.dirname(checkpoint_path)

# %%
print("[INFO] indexing file images BreaKHis dataset...")
using_magnification = '400X'
base_dataset = "binary_scenario"
class_dir = ['benign', 'malignant']
type_dataset = ['val', 'train']
dataset_train = []
dataset_val = []
for type_set in type_dataset:
    for class_item in class_dir:
        cur_dir = os.path.join(base_dataset, type_set, using_magnification ,class_item)
        for file in os.listdir(cur_dir):
            if type_set == 'train':
                dataset_train.append(os.path.join(cur_dir, file))
            else:
                dataset_val.append(os.path.join(cur_dir, file))
# Out:
# [INFO] indexing file images BreaKHis dataset...

# %%
print("[INFO] load images BreaKHis dataset...")
#  load images
train_images = []
val_images = []
for type_set in type_dataset:
    cur_dataset = dataset_train if type_set == 'train' else dataset_val
    for image_path in cur_dataset:
        if ".png" in image_path:
            image = cv2.imread(image_path)
            image = cv2.resize(image, IMAGE_SIZE)
            if type_set == 'train':
                train_images.append(image)
            else:
                val_images.append(image)
# Out:
# [INFO] load images BreaKHis dataset...

# %%
# normalization
print("[INFO] normalization...")
train_x = np.array(train_images).astype("float32") / 255.0
val_x = np.array(val_images).astype("float32") / 255.0
# Out:
# [INFO] normalization...

# %%
print("[INFO] building auto encoder...")
auto_encoder = ConvAutoEncoder.build(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)
opt = Adam(learning_rate=INIT_LR)
checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_path,
    save_weights_only=True,
    monitor="val_loss",
    verbose = 1,
    mode='min',
    save_best_only=True)
auto_encoder.compile(loss="mse", optimizer=opt)
auto_encoder.summary()
# Out:
# [INFO] building auto encoder...
# Model: "auto_encoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 128, 128, 128)  │         3,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu (LeakyReLU)         │ (None, 128, 128, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ enc_filter_128                  │ (None, 128, 128, 128)  │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2097152)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ encoded (Dense)                 │ (None, 48)             │   100,663,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 2097152)        │   102,760,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 128, 128, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose                │ (None, 256, 256, 128)  │       147,584 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_1 (LeakyReLU)       │ (None, 256, 256, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dec_filter_128                  │ (None, 256, 256, 128)  │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_1              │ (None, 256, 256, 3)    │         3,459 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ decoded (Activation)            │ (None, 256, 256, 3)    │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 203,579,443 (776.59 MB)
#  Trainable params: 203,578,931 (776.59 MB)
#  Non-trainable params: 512 (2.00 KB)

# %%
# train the convolutional auto encoder
print("[INFO] training auto encoder...")
H = auto_encoder.fit(
    train_x, train_x,
    shuffle=True,
    validation_data=(val_x, val_x),
    epochs=EPOCHS,
    callbacks = [checkpoint_callback],
    batch_size=BS)
# Out:
# [INFO] training auto encoder...
# Epoch 1/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 538ms/step - loss: 0.0780
# Epoch 1: val_loss improved from None to 0.02394, saving model to training_1_400/cp.ckpt.weights.h5
#
# Epoch 1: finished saving model to training_1_400/cp.ckpt.weights.h5
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - loss: 0.0554 - val_loss: 0.0239
# Epoch 2/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - loss: 0.0246
# Epoch 2: val_loss improved from 0.02394 to 0.02294, saving model to training_1_400/cp.ckpt.weights.h5
#
# Epoch 2: finished saving model to training_1_400/cp.ckpt.weights.h5
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 73s 2s/step - loss: 0.0226 - val_loss: 0.0229
# Epoch 3/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - loss: 0.0198
# Epoch 3: val_loss improved from 0.02294 to 0.02229, saving model to training_1_400/cp.ckpt.weights.h5
#
# Epoch 3: finished saving model to training_1_400/cp.ckpt.weights.h5
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 84s 2s/step - loss: 0.0195 - val_loss: 0.0223
# Epoch 4/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - loss: 0.0176
# Epoch 4: val_loss improved from 0.02229 to 0.02203, saving model to training_1_400/cp.ckpt.weights.h5
#
# Epoch 4: finished saving model to training_1_400/cp.ckpt.weights.h5
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - loss: 0.0176 - val_loss: 0.0220
# Epoch 5/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - loss: 0.0177
# Epoch 5: val_loss improved from 0.02203 to 0.02101, saving model to training_1_400/cp.ckpt.weights.h5
#
# Epoch 5: finished saving model to training_1_400/cp.ckpt.weights.h5
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 60s 1s/step - loss: 0.0175 - val_loss: 0.0210
# Epoch 6/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - loss: 0.0166
# Epoch 6: val_loss improved from 0.02101 to 0.02046, saving model to training_1_400/cp.ckpt.weights.h5
#
# Epoch 6: finished saving model to training_1_400/cp.ckpt.weights.h5
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 58s 1s/step - loss: 0.0164 - val_loss: 0.0205
# Epoch 7/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - loss: 0.0163
# Epoch 7: val_loss improved from 0.02046 to 0.01975, saving model to training_1_400/cp.ckpt.weights.h5
#
# Epoch 7: finished saving model to training_1_400/cp.ckpt.weights.h5
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 59s 1s/step - loss: 0.0160 - val_loss: 0.0197
# Epoch 8/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - loss: 0.0158
# Epoch 8: val_loss improved from 0.01975 to 0.01919, saving model to training_1_400/cp.ckpt.weights.h5
#
# Epoch 8: finished saving model to training_1_400/cp.ckpt.weights.h5
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 49s 1s/step - loss: 0.0156 - val_loss: 0.0192
# Epoch 9/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - loss: 0.0156
# Epoch 9: val_loss improved from 0.01919 to 0.01742, saving model to training_1_400/cp.ckpt.weights.h5
#
# Epoch 9: finished saving model to training_1_400/cp.ckpt.weights.h5
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 75s 2s/step - loss: 0.0152 - val_loss: 0.0174
# Epoch 10/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - loss: 0.0151
# Epoch 10: val_loss improved from 0.01742 to 0.01664, saving model to training_1_400/cp.ckpt.weights.h5
#
# Epoch 10: finished saving model to training_1_400/cp.ckpt.weights.h5
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 75s 2s/step - loss: 0.0148 - val_loss: 0.0166
# Epoch 11/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - loss: 0.0144
# Epoch 11: val_loss improved from 0.01664 to 0.01596, saving model to training_1_400/cp.ckpt.weights.h5
#
# Epoch 11: finished saving model to training_1_400/cp.ckpt.weights.h5
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 84s 2s/step - loss: 0.0143 - val_loss: 0.0160
# Epoch 12/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - loss: 0.0135
# Epoch 12: val_loss improved from 0.01596 to 0.01538, saving model to training_1_400/cp.ckpt.weights.h5
#
# Epoch 12: finished saving model to training_1_400/cp.ckpt.weights.h5
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - loss: 0.0139 - val_loss: 0.0154
# Epoch 13/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - loss: 0.0136
# Epoch 13: val_loss did not improve from 0.01538
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 17s 367ms/step - loss: 0.0135 - val_loss: 0.0154
# Epoch 14/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - loss: 0.0132
# Epoch 14: val_loss improved from 0.01538 to 0.01432, saving model to training_1_400/cp.ckpt.weights.h5
#
# Epoch 14: finished saving model to training_1_400/cp.ckpt.weights.h5
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 78s 2s/step - loss: 0.0131 - val_loss: 0.0143
# Epoch 15/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - loss: 0.0126
# Epoch 15: val_loss improved from 0.01432 to 0.01399, saving model to training_1_400/cp.ckpt.weights.h5
#
# Epoch 15: finished saving model to training_1_400/cp.ckpt.weights.h5
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 66s 1s/step - loss: 0.0129 - val_loss: 0.0140
# Epoch 16/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - loss: 0.0125
# Epoch 16: val_loss improved from 0.01399 to 0.01360, saving model to training_1_400/cp.ckpt.weights.h5
#
# Epoch 16: finished saving model to training_1_400/cp.ckpt.weights.h5
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 85s 2s/step - loss: 0.0125 - val_loss: 0.0136
# Epoch 17/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - loss: 0.0119
# Epoch 17: val_loss did not improve from 0.01360
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 17s 352ms/step - loss: 0.0120 - val_loss: 0.0186
# Epoch 18/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - loss: 0.0130
# Epoch 18: val_loss did not improve from 0.01360
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 17s 365ms/step - loss: 0.0125 - val_loss: 0.0143
# Epoch 19/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - loss: 0.0117
# Epoch 19: val_loss did not improve from 0.01360
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 18s 372ms/step - loss: 0.0118 - val_loss: 0.0143
# Epoch 20/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step - loss: 0.0115
# Epoch 20: val_loss did not improve from 0.01360
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 18s 378ms/step - loss: 0.0119 - val_loss: 0.0148
# Epoch 21/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - loss: 0.0110
# Epoch 21: val_loss did not improve from 0.01360
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 18s 385ms/step - loss: 0.0112 - val_loss: 0.0156
# Epoch 22/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step - loss: 0.0107
# Epoch 22: val_loss did not improve from 0.01360
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 19s 410ms/step - loss: 0.0108 - val_loss: 0.0157
# Epoch 23/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step - loss: 0.0104
# Epoch 23: val_loss did not improve from 0.01360
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 19s 401ms/step - loss: 0.0104 - val_loss: 0.0144
# Epoch 24/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step - loss: 0.0098
# Epoch 24: val_loss did not improve from 0.01360
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 19s 412ms/step - loss: 0.0100 - val_loss: 0.0150
# Epoch 25/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step - loss: 0.0095
# Epoch 25: val_loss did not improve from 0.01360
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 19s 410ms/step - loss: 0.0098 - val_loss: 0.0161
# Epoch 26/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step - loss: 0.0095
# Epoch 26: val_loss did not improve from 0.01360
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 19s 402ms/step - loss: 0.0097 - val_loss: 0.0155
# Epoch 27/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step - loss: 0.0086
# Epoch 27: val_loss did not improve from 0.01360
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 19s 401ms/step - loss: 0.0089 - val_loss: 0.0154
# Epoch 28/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step - loss: 0.0084
# Epoch 28: val_loss did not improve from 0.01360
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 19s 401ms/step - loss: 0.0085 - val_loss: 0.0175
# Epoch 29/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step - loss: 0.0097
# Epoch 29: val_loss did not improve from 0.01360
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 19s 402ms/step - loss: 0.0093 - val_loss: 0.0168
# Epoch 30/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step - loss: 0.0078
# Epoch 30: val_loss did not improve from 0.01360
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 19s 405ms/step - loss: 0.0081 - val_loss: 0.0159
# Epoch 31/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step - loss: 0.0083
# Epoch 31: val_loss did not improve from 0.01360
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 19s 404ms/step - loss: 0.0083 - val_loss: 0.0164
# Epoch 32/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step - loss: 0.0074
# Epoch 32: val_loss did not improve from 0.01360
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 19s 405ms/step - loss: 0.0076 - val_loss: 0.0170
# Epoch 33/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step - loss: 0.0077
# Epoch 33: val_loss did not improve from 0.01360
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 19s 406ms/step - loss: 0.0075 - val_loss: 0.0162
# Epoch 34/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - loss: 0.0068
# Epoch 34: val_loss did not improve from 0.01360
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 19s 406ms/step - loss: 0.0071 - val_loss: 0.0168
# Epoch 35/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step - loss: 0.0068
# Epoch 35: val_loss did not improve from 0.01360
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 19s 404ms/step - loss: 0.0071 - val_loss: 0.0171
# Epoch 36/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step - loss: 0.0071
# Epoch 36: val_loss did not improve from 0.01360
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 20s 417ms/step - loss: 0.0070 - val_loss: 0.0164
# Epoch 37/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step - loss: 0.0063
# Epoch 37: val_loss did not improve from 0.01360
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 19s 403ms/step - loss: 0.0066 - val_loss: 0.0180
# Epoch 38/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step - loss: 0.0070
# Epoch 38: val_loss did not improve from 0.01360
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 19s 404ms/step - loss: 0.0071 - val_loss: 0.0174
# Epoch 39/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step - loss: 0.0059
# Epoch 39: val_loss did not improve from 0.01360
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 19s 407ms/step - loss: 0.0060 - val_loss: 0.0169
# Epoch 40/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step - loss: 0.0056
# Epoch 40: val_loss did not improve from 0.01360
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 19s 404ms/step - loss: 0.0058 - val_loss: 0.0179
# Epoch 41/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step - loss: 0.0060
# Epoch 41: val_loss did not improve from 0.01360
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 19s 405ms/step - loss: 0.0061 - val_loss: 0.0172
# Epoch 42/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - loss: 0.0055
# Epoch 42: val_loss did not improve from 0.01360
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 19s 407ms/step - loss: 0.0057 - val_loss: 0.0175
# Epoch 43/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step - loss: 0.0052
# Epoch 43: val_loss did not improve from 0.01360
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 19s 405ms/step - loss: 0.0054 - val_loss: 0.0170
# Epoch 44/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step - loss: 0.0050
# Epoch 44: val_loss did not improve from 0.01360
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 19s 407ms/step - loss: 0.0051 - val_loss: 0.0171
# Epoch 45/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step - loss: 0.0046
# Epoch 45: val_loss did not improve from 0.01360
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 19s 404ms/step - loss: 0.0048 - val_loss: 0.0172
# Epoch 46/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step - loss: 0.0045
# Epoch 46: val_loss did not improve from 0.01360
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 19s 404ms/step - loss: 0.0046 - val_loss: 0.0182
# Epoch 47/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step - loss: 0.0052
# Epoch 47: val_loss did not improve from 0.01360
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 19s 407ms/step - loss: 0.0049 - val_loss: 0.0181
# Epoch 48/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step - loss: 0.0048
# Epoch 48: val_loss did not improve from 0.01360
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 19s 406ms/step - loss: 0.0048 - val_loss: 0.0176
# Epoch 49/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step - loss: 0.0043
# Epoch 49: val_loss did not improve from 0.01360
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 19s 405ms/step - loss: 0.0043 - val_loss: 0.0176
# Epoch 50/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - loss: 0.0041
# Epoch 50: val_loss did not improve from 0.01360
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 19s 408ms/step - loss: 0.0042 - val_loss: 0.0175

# %%
print("[INFO] making predictions...")
decoded = auto_encoder.predict(val_x)
vis = visualize_predictions(decoded, val_x)
image_example_path = "reconstruction"
cv2.imwrite(os.path.join(image_example_path,"recon_vis.png"), vis)
N = np.arange(0, EPOCHS)
plt.figure(figsize=(15,7))
plt.plot(N, H.history["loss"], label="train_loss")
plt.plot(N, H.history["val_loss"], label="val_loss")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.show()
# Out:
# [INFO] making predictions...
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 194ms/step

# %%
with open('training_1_400.json', 'w') as f:
    json.dump(H.history, f)

# %%
auto_encoder.save('training_1_400.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
