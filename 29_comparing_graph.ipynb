# %% [markdown]
# <a href="https://colab.research.google.com/github/thisishasan/cbir_system/blob/main/29_comparing_graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd '/content/drive/My Drive/01_information_retrieval'
# Out:
# /content/drive/My Drive/01_information_retrieval

# %%
import json

with open('training_1_400.json') as f:
  training_400_main = json.load(f)

with open('training_1_400_subclass.json') as f:
  training_400_sub = json.load(f)

with open('training_1_200.json') as f:
  training_200_main = json.load(f)

with open('training_1_200_subclass.json') as f:
  training_200_sub = json.load(f)

with open('training_1_100.json') as f:
  training_100_main = json.load(f)

with open('training_1_100_subclass.json') as f:
  training_100_sub = json.load(f)

with open('training_1_40.json') as f:
  training_40_main = json.load(f)

with open('training_1_40_subclass.json') as f:
  training_40_sub = json.load(f)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(30,7))

ax = plt.subplot(1,2,1)
sns.set(font_scale=2)
sns.lineplot(x=range(0, len(training_400_main['loss'])), y=training_400_main['loss'], linestyle='-', marker='^', label="400X")
sns.lineplot(x=range(0, len(training_200_main['loss'])), y=training_200_main['loss'], linestyle='-', marker='o', label="200X")
sns.lineplot(x=range(0, len(training_100_main['loss'])), y=training_100_main['loss'], linestyle='-', marker='>', label="100X")
sns.lineplot(x=range(0, len(training_40_main['loss'])), y=training_40_main['loss'], linestyle='-', marker='v', label="40X")
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim(0, 0.02)
plt.title('Loss value in the Main Class')
ax.xaxis.grid()
ax = plt.subplot(1,2,2)
sns.set(font_scale=2)
sns.lineplot(x=range(0, len(training_400_sub['loss'])), y=training_400_sub['loss'], linestyle='-', marker='^', label="400X")
sns.lineplot(x=range(0, len(training_200_sub['loss'])), y=training_200_sub['loss'], linestyle='-', marker='o', label="200X")
sns.lineplot(x=range(0, len(training_100_sub['loss'])), y=training_100_sub['loss'], linestyle='-', marker='>', label="100X")
sns.lineplot(x=range(0, len(training_40_sub['loss'])), y=training_40_sub['loss'], linestyle='-', marker='v', label="40X")
plt.xlabel('Epoch')
plt.title('Loss value in the subclass')
plt.ylabel('Loss')
plt.ylim(0, 0.02)
ax.xaxis.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
ax = plt.figure(figsize=(20,20))
sns.set(font_scale=2)
sns.lineplot(x=range(0, len(training_400_main['loss'])), y=training_400_main['loss'], linestyle='-',linewidth = 3, label="400X")
sns.lineplot(x=range(0, len(training_200_main['loss'])), y=training_200_main['loss'], linestyle='-', linewidth = 3,label="200X")
sns.lineplot(x=range(0, len(training_100_main['loss'])), y=training_100_main['loss'], linestyle='-',  linewidth = 3,label="100X")
g = sns.lineplot(x=range(0, len(training_40_main['loss'])), y=training_40_main['loss'], linestyle='-',linewidth = 3, label="40X")
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim(0, 0.02)
plt.title('Loss values on main classes')
plt.savefig('loss-main-class.svg',format='svg')
plt.show()

# %%
plt.figure(figsize=(20,20))
sns.set(font_scale=2)
sns.lineplot(x=range(0, len(training_400_sub['loss'])), y=training_400_sub['loss'], linestyle='-', linewidth = 3, label="400X")
sns.lineplot(x=range(0, len(training_200_sub['loss'])), y=training_200_sub['loss'], linestyle='-', linewidth = 3, label="200X")
sns.lineplot(x=range(0, len(training_100_sub['loss'])), y=training_100_sub['loss'], linestyle='-', linewidth = 3, label="100X")
sns.lineplot(x=range(0, len(training_40_sub['loss'])), y=training_40_sub['loss'], linestyle='-', linewidth = 3, label="40X")
plt.xlabel('Epoch')
plt.title('Loss values on subclasses')
plt.ylabel('Loss')
plt.ylim(0, 0.02)
plt.savefig('loss-sub-class.svg',format='svg')
plt.show()
