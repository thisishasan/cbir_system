# %% [markdown]
# <a href="https://colab.research.google.com/github/thisishasan/cbir_system/blob/main/03_train_auto_encoder_magnification_1_40.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/My Drive/01_information_retrieval'
# !ls
# Out:
# /content/drive/My Drive/01_information_retrieval
# binary_scenario  Notes.gdoc  original  subclass_scenario

# %%
import matplotlib
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
import numpy as np
import cv2
import os
import json

# %%
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import Conv2DTranspose
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Reshape
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
import numpy as np

# %%
class ConvAutoEncoder:
    @staticmethod
    def build(width, height, depth, filters=(128,), latent_dim=48):
        input_shape = (height, width, depth)
        channel_dim = -1
        inputs = Input(shape=input_shape)
        x = inputs
        # Encoder layer
        for f in filters:
            x = Conv2D(f, (3, 3), strides=2, padding='same')(x)
            x = LeakyReLU(negative_slope=0.2)(x)
            x = BatchNormalization(axis=channel_dim, name='enc_filter_'+str(f))(x)

        volume_size = K.int_shape(x)
        x = Flatten()(x)
        # Latent layer
        latent = Dense(latent_dim, name="encoded")(x)

        # Decoder layer
        x = Dense(int(np.prod(volume_size[1:])))(latent)
        x = Reshape((volume_size[1], volume_size[2], volume_size[3]))(x)

        # Reverse on decoder
        for f in filters[::-1]:
            x = Conv2DTranspose(f, (3, 3), strides=2, padding='same')(x)
            x = LeakyReLU(negative_slope=0.2)(x)
            x = BatchNormalization(axis=channel_dim, name='dec_filter_'+str(f))(x)

        x = Conv2DTranspose(depth, (3, 3), padding="same")(x)
        outputs = Activation("sigmoid", name="decoded")(x)

        auto_encoder = Model(inputs, outputs, name="auto_encoder")
        return auto_encoder

# %%
def visualize_predictions(_decoded, gt, samples=10):
    outputs = None
    for i in range(0, samples):
        original = (gt[i] * 255).astype("uint8")
        recon = (_decoded[i] * 255).astype("uint8")
        output = np.hstack([original, recon])
        outputs = output if outputs is None else np.vstack([outputs, output])
    return outputs

# %%
EPOCHS = 50
INIT_LR = 1e-3
BS = 32
IMAGE_SIZE = (256, 256)
checkpoint_path = "training_1_40/cp.ckpt.weights.h5"
checkpoint_dir = os.path.dirname(checkpoint_path)

# %%
print("[INFO] indexing file images BreaKHis dataset...")
using_magnification = '40X'
base_dataset = "binary_scenario"
class_dir = ['benign', 'malignant']
type_dataset = ['val', 'train']
dataset_train = []
dataset_val = []
for type_set in type_dataset:
    for class_item in class_dir:
        cur_dir = os.path.join(base_dataset, type_set, using_magnification ,class_item)
        for file in os.listdir(cur_dir):
            if type_set == 'train':
                dataset_train.append(os.path.join(cur_dir, file))
            else:
                dataset_val.append(os.path.join(cur_dir, file))
# Out:
# [INFO] indexing file images BreaKHis dataset...

# %%
print("[INFO] load images BreaKHis dataset...")
#  load images
train_images = []
val_images = []
for type_set in type_dataset:
    cur_dataset = dataset_train if type_set == 'train' else dataset_val
    for image_path in cur_dataset:
        if ".png" in image_path:
            image = cv2.imread(image_path)
            image = cv2.resize(image, IMAGE_SIZE)
            if type_set == 'train':
                train_images.append(image)
            else:
                val_images.append(image)
# Out:
# [INFO] load images BreaKHis dataset...

# %%
# normalization
print("[INFO] normalization...")
train_x = np.array(train_images).astype("float32") / 255.0
val_x = np.array(val_images).astype("float32") / 255.0
# Out:
# [INFO] normalization...

# %%
print("[INFO] building auto encoder...")
auto_encoder = ConvAutoEncoder.build(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)
opt = Adam(learning_rate=INIT_LR)
checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_path,
    save_weights_only=True,
    monitor="val_loss",
    verbose = 1,
    mode='min',
    save_best_only=True)
auto_encoder.compile(loss="mse", optimizer=opt)
auto_encoder.summary()
# Out:
# [INFO] building auto encoder...
# Model: "auto_encoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_6 (InputLayer)      │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 128, 128, 128)  │         3,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_10 (LeakyReLU)      │ (None, 128, 128, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ enc_filter_128                  │ (None, 128, 128, 128)  │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_6 (Flatten)             │ (None, 2097152)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ encoded (Dense)                 │ (None, 48)             │   100,663,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 2097152)        │   102,760,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_4 (Reshape)             │ (None, 128, 128, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_8              │ (None, 256, 256, 128)  │       147,584 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_11 (LeakyReLU)      │ (None, 256, 256, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dec_filter_128                  │ (None, 256, 256, 128)  │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_9              │ (None, 256, 256, 3)    │         3,459 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ decoded (Activation)            │ (None, 256, 256, 3)    │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 203,579,443 (776.59 MB)
#  Trainable params: 203,578,931 (776.59 MB)
#  Non-trainable params: 512 (2.00 KB)

# %%
# train the convolutional auto encoder
print("[INFO] training auto encoder...")
H = auto_encoder.fit(
    train_x, train_x,
    shuffle=True,
    validation_data=(val_x, val_x),
    epochs=EPOCHS,
    callbacks = [checkpoint_callback],
    batch_size=BS)
# Out:
# [INFO] training auto encoder...
# Epoch 1/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 621ms/step - loss: 0.0873
# Epoch 1: val_loss improved from None to 0.01600, saving model to training_1_40/cp.ckpt.weights.h5
#
# Epoch 1: finished saving model to training_1_40/cp.ckpt.weights.h5
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - loss: 0.0615 - val_loss: 0.0160
# Epoch 2/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - loss: 0.0200
# Epoch 2: val_loss improved from 0.01600 to 0.01453, saving model to training_1_40/cp.ckpt.weights.h5
#
# Epoch 2: finished saving model to training_1_40/cp.ckpt.weights.h5
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - loss: 0.0179 - val_loss: 0.0145
# Epoch 3/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - loss: 0.0116
# Epoch 3: val_loss did not improve from 0.01453
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 18s 347ms/step - loss: 0.0111 - val_loss: 0.0168
# Epoch 4/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - loss: 0.0103
# Epoch 4: val_loss did not improve from 0.01453
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 19s 370ms/step - loss: 0.0103 - val_loss: 0.0213
# Epoch 5/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - loss: 0.0099
# Epoch 5: val_loss did not improve from 0.01453
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 19s 373ms/step - loss: 0.0101 - val_loss: 0.0200
# Epoch 6/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - loss: 0.0101
# Epoch 6: val_loss did not improve from 0.01453
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 19s 368ms/step - loss: 0.0100 - val_loss: 0.0195
# Epoch 7/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - loss: 0.0098
# Epoch 7: val_loss did not improve from 0.01453
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 19s 369ms/step - loss: 0.0099 - val_loss: 0.0182
# Epoch 8/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - loss: 0.0098
# Epoch 8: val_loss did not improve from 0.01453
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 18s 357ms/step - loss: 0.0098 - val_loss: 0.0176
# Epoch 9/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - loss: 0.0095
# Epoch 9: val_loss did not improve from 0.01453
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 20s 393ms/step - loss: 0.0097 - val_loss: 0.0154
# Epoch 10/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - loss: 0.0095
# Epoch 10: val_loss improved from 0.01453 to 0.01390, saving model to training_1_40/cp.ckpt.weights.h5
#
# Epoch 10: finished saving model to training_1_40/cp.ckpt.weights.h5
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 112s 2s/step - loss: 0.0096 - val_loss: 0.0139
# Epoch 11/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - loss: 0.0095
# Epoch 11: val_loss improved from 0.01390 to 0.01072, saving model to training_1_40/cp.ckpt.weights.h5
#
# Epoch 11: finished saving model to training_1_40/cp.ckpt.weights.h5
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - loss: 0.0096 - val_loss: 0.0107
# Epoch 12/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - loss: 0.0097
# Epoch 12: val_loss improved from 0.01072 to 0.01010, saving model to training_1_40/cp.ckpt.weights.h5
#
# Epoch 12: finished saving model to training_1_40/cp.ckpt.weights.h5
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 84s 2s/step - loss: 0.0096 - val_loss: 0.0101
# Epoch 13/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - loss: 0.0094
# Epoch 13: val_loss did not improve from 0.01010
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 18s 360ms/step - loss: 0.0094 - val_loss: 0.0122
# Epoch 14/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - loss: 0.0094
# Epoch 14: val_loss did not improve from 0.01010
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 19s 375ms/step - loss: 0.0094 - val_loss: 0.0101
# Epoch 15/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - loss: 0.0093
# Epoch 15: val_loss improved from 0.01010 to 0.00952, saving model to training_1_40/cp.ckpt.weights.h5
#
# Epoch 15: finished saving model to training_1_40/cp.ckpt.weights.h5
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 77s 2s/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 16/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - loss: 0.0088
# Epoch 16: val_loss improved from 0.00952 to 0.00917, saving model to training_1_40/cp.ckpt.weights.h5
#
# Epoch 16: finished saving model to training_1_40/cp.ckpt.weights.h5
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 80s 2s/step - loss: 0.0092 - val_loss: 0.0092
# Epoch 17/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - loss: 0.0091
# Epoch 17: val_loss did not improve from 0.00917
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 19s 365ms/step - loss: 0.0092 - val_loss: 0.0093
# Epoch 18/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - loss: 0.0089
# Epoch 18: val_loss improved from 0.00917 to 0.00910, saving model to training_1_40/cp.ckpt.weights.h5
#
# Epoch 18: finished saving model to training_1_40/cp.ckpt.weights.h5
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 90s 2s/step - loss: 0.0091 - val_loss: 0.0091
# Epoch 19/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - loss: 0.0090
# Epoch 19: val_loss did not improve from 0.00910
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 18s 357ms/step - loss: 0.0091 - val_loss: 0.0116
# Epoch 20/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - loss: 0.0090
# Epoch 20: val_loss did not improve from 0.00910
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 19s 373ms/step - loss: 0.0091 - val_loss: 0.0158
# Epoch 21/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - loss: 0.0089
# Epoch 21: val_loss did not improve from 0.00910
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 19s 375ms/step - loss: 0.0089 - val_loss: 0.0096
# Epoch 22/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - loss: 0.0087
# Epoch 22: val_loss did not improve from 0.00910
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 20s 366ms/step - loss: 0.0089 - val_loss: 0.0093
# Epoch 23/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - loss: 0.0088
# Epoch 23: val_loss did not improve from 0.00910
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 19s 374ms/step - loss: 0.0087 - val_loss: 0.0092
# Epoch 24/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - loss: 0.0085
# Epoch 24: val_loss did not improve from 0.00910
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 18s 358ms/step - loss: 0.0087 - val_loss: 0.0093
# Epoch 25/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - loss: 0.0085
# Epoch 25: val_loss did not improve from 0.00910
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 19s 374ms/step - loss: 0.0086 - val_loss: 0.0092
# Epoch 26/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - loss: 0.0082
# Epoch 26: val_loss did not improve from 0.00910
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 20s 361ms/step - loss: 0.0085 - val_loss: 0.0105
# Epoch 27/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - loss: 0.0083
# Epoch 27: val_loss did not improve from 0.00910
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 19s 371ms/step - loss: 0.0084 - val_loss: 0.0104
# Epoch 28/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - loss: 0.0080
# Epoch 28: val_loss did not improve from 0.00910
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 18s 360ms/step - loss: 0.0083 - val_loss: 0.0096
# Epoch 29/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - loss: 0.0080
# Epoch 29: val_loss did not improve from 0.00910
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 18s 360ms/step - loss: 0.0082 - val_loss: 0.0103
# Epoch 30/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - loss: 0.0085
# Epoch 30: val_loss did not improve from 0.00910
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 18s 359ms/step - loss: 0.0084 - val_loss: 0.0121
# Epoch 31/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - loss: 0.0080
# Epoch 31: val_loss did not improve from 0.00910
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 18s 360ms/step - loss: 0.0079 - val_loss: 0.0102
# Epoch 32/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - loss: 0.0076
# Epoch 32: val_loss did not improve from 0.00910
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 18s 359ms/step - loss: 0.0077 - val_loss: 0.0092
# Epoch 33/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - loss: 0.0073
# Epoch 33: val_loss did not improve from 0.00910
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 18s 360ms/step - loss: 0.0076 - val_loss: 0.0099
# Epoch 34/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - loss: 0.0075
# Epoch 34: val_loss did not improve from 0.00910
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 19s 370ms/step - loss: 0.0074 - val_loss: 0.0098
# Epoch 35/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - loss: 0.0073
# Epoch 35: val_loss did not improve from 0.00910
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 18s 360ms/step - loss: 0.0075 - val_loss: 0.0099
# Epoch 36/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - loss: 0.0074
# Epoch 36: val_loss did not improve from 0.00910
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 18s 361ms/step - loss: 0.0073 - val_loss: 0.0097
# Epoch 37/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - loss: 0.0068
# Epoch 37: val_loss did not improve from 0.00910
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 19s 373ms/step - loss: 0.0070 - val_loss: 0.0096
# Epoch 38/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - loss: 0.0068
# Epoch 38: val_loss did not improve from 0.00910
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 20s 359ms/step - loss: 0.0070 - val_loss: 0.0099
# Epoch 39/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - loss: 0.0067
# Epoch 39: val_loss did not improve from 0.00910
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 18s 360ms/step - loss: 0.0069 - val_loss: 0.0117
# Epoch 40/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - loss: 0.0068
# Epoch 40: val_loss did not improve from 0.00910
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 19s 373ms/step - loss: 0.0068 - val_loss: 0.0096
# Epoch 41/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - loss: 0.0064
# Epoch 41: val_loss did not improve from 0.00910
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 18s 359ms/step - loss: 0.0066 - val_loss: 0.0097
# Epoch 42/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - loss: 0.0064
# Epoch 42: val_loss did not improve from 0.00910
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 18s 360ms/step - loss: 0.0065 - val_loss: 0.0113
# Epoch 43/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - loss: 0.0061
# Epoch 43: val_loss did not improve from 0.00910
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 18s 362ms/step - loss: 0.0063 - val_loss: 0.0107
# Epoch 44/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - loss: 0.0062
# Epoch 44: val_loss did not improve from 0.00910
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 18s 360ms/step - loss: 0.0063 - val_loss: 0.0099
# Epoch 45/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - loss: 0.0058
# Epoch 45: val_loss did not improve from 0.00910
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 18s 359ms/step - loss: 0.0060 - val_loss: 0.0121
# Epoch 46/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - loss: 0.0058
# Epoch 46: val_loss did not improve from 0.00910
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 19s 372ms/step - loss: 0.0060 - val_loss: 0.0099
# Epoch 47/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - loss: 0.0056
# Epoch 47: val_loss did not improve from 0.00910
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 18s 359ms/step - loss: 0.0058 - val_loss: 0.0098
# Epoch 48/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - loss: 0.0055
# Epoch 48: val_loss did not improve from 0.00910
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 18s 361ms/step - loss: 0.0056 - val_loss: 0.0098
# Epoch 49/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - loss: 0.0053
# Epoch 49: val_loss did not improve from 0.00910
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 18s 361ms/step - loss: 0.0053 - val_loss: 0.0106
# Epoch 50/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - loss: 0.0052
# Epoch 50: val_loss did not improve from 0.00910
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 18s 361ms/step - loss: 0.0052 - val_loss: 0.0100

# %%
print("[INFO] making predictions...")
decoded = auto_encoder.predict(val_x)
vis = visualize_predictions(decoded, val_x)
image_example_path = "reconstruction"
cv2.imwrite(os.path.join(image_example_path,"recon_vis_40X_binary.png"), vis)
N = np.arange(0, EPOCHS)
plt.figure(figsize=(15,7))
plt.plot(N, H.history["loss"], label="train_loss")
plt.plot(N, H.history["val_loss"], label="val_loss")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.show()
# Out:
# [INFO] making predictions...
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 195ms/step

# %%
with open('training_1_40.json', 'w') as f:
    json.dump(H.history, f)

# %%
auto_encoder.save('training_1_40.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
