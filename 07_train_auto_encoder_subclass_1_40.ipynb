# %% [markdown]
# <a href="https://colab.research.google.com/github/thisishasan/cbir_system/blob/main/07_train_auto_encoder_subclass_1_40.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/My Drive/01_information_retrieval'
# !ls
# Out:
# /content/drive/My Drive/01_information_retrieval
# binary_scenario    training_1_100.json	training_1_400.json
# Notes.gdoc	   training_1_200	training_1_40.h5
# original	   training_1_200.h5	training_1_40.json
# subclass_scenario  training_1_200.json	training_1_indexed_100.json
# tflite_model	   training_1_40	training_1_indexed_200.json
# training_1_100	   training_1_400	training_1_indexed_400.json
# training_1_100.h5  training_1_400.h5	training_1_indexed_40.json

# %%
import matplotlib
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
import numpy as np
import cv2
import os
import json

# %%
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import Conv2DTranspose
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Reshape
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
import numpy as np

# %%
class ConvAutoEncoder:
    @staticmethod
    def build(width, height, depth, filters=(128,), latent_dim=48):
        input_shape = (height, width, depth)
        channel_dim = -1
        inputs = Input(shape=input_shape)
        x = inputs
        # Encoder layer
        for f in filters:
            x = Conv2D(f, (3, 3), strides=2, padding='same')(x)
            x = LeakyReLU(negative_slope=0.2)(x)
            x = BatchNormalization(axis=channel_dim, name='enc_filter_'+str(f))(x)

        volume_size = K.int_shape(x)
        x = Flatten()(x)
        # Latent layer
        latent = Dense(latent_dim, name="encoded")(x)

        # Decoder layer
        x = Dense(int(np.prod(volume_size[1:])))(latent)
        x = Reshape((volume_size[1], volume_size[2], volume_size[3]))(x)

        # Reverse on decoder
        for f in filters[::-1]:
            x = Conv2DTranspose(f, (3, 3), strides=2, padding='same')(x)
            x = LeakyReLU(negative_slope=0.2)(x)
            x = BatchNormalization(axis=channel_dim, name='dec_filter_'+str(f))(x)

        x = Conv2DTranspose(depth, (3, 3), padding="same")(x)
        outputs = Activation("sigmoid", name="decoded")(x)

        auto_encoder = Model(inputs, outputs, name="auto_encoder")
        return auto_encoder

# %%
def visualize_predictions(_decoded, gt, samples=10):
    outputs = None
    for i in range(0, samples):
        original = (gt[i] * 255).astype("uint8")
        recon = (_decoded[i] * 255).astype("uint8")
        output = np.hstack([original, recon])
        outputs = output if outputs is None else np.vstack([outputs, output])
    return outputs

# %%
EPOCHS = 50
INIT_LR = 1e-3
BS = 32
IMAGE_SIZE = (256, 256)
checkpoint_path = "training_1_40_subclass/cp.ckpt.weights.h5"
checkpoint_dir = os.path.dirname(checkpoint_path)

# %%
print("[INFO] indexing file images BreaKHis dataset...")
base_dataset = "subclass_scenario"
magnification = "40X"
class_dir = ['tubular_adenoma', 'phyllodes_tumor', 'papillary_carcinoma',
             'mucinous_carcinoma', 'lobular_carcinoma', 'fibroadenoma',
             'ductal_carcinoma', 'adenosis'
             ]
type_dataset = ['val', 'train']
dataset_train = []
dataset_val = []
for type_set in type_dataset:
    for class_item in class_dir:
        cur_dir = os.path.join(base_dataset, type_set, magnification ,class_item)
        for file in os.listdir(cur_dir):
            if type_set == 'train':
                dataset_train.append(os.path.join(cur_dir, file))
            else:
                dataset_val.append(os.path.join(cur_dir, file))
# Out:
# [INFO] indexing file images BreaKHis dataset...

# %%
print("[INFO] load images BreaKHis dataset...")
#  load images
train_images = []
val_images = []
for type_set in type_dataset:
    cur_dataset = dataset_train if type_set == 'train' else dataset_val
    for image_path in cur_dataset:
        if ".png" in image_path:
            image = cv2.imread(image_path)
            image = cv2.resize(image, IMAGE_SIZE)
            if type_set == 'train':
                train_images.append(image)
            else:
                val_images.append(image)
# Out:
# [INFO] load images BreaKHis dataset...

# %%
# normalization
print("[INFO] normalization...")
train_x = np.array(train_images).astype("float32") / 255.0
val_x = np.array(val_images).astype("float32") / 255.0
# Out:
# [INFO] normalization...

# %%
print("[INFO] building auto encoder...")
auto_encoder = ConvAutoEncoder.build(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)
opt = Adam(learning_rate=INIT_LR)
checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_path,
    save_weights_only=True,
    monitor="val_loss",
    verbose = 1,
    mode='min',
    save_best_only=True)
auto_encoder.compile(loss="mse", optimizer=opt)
auto_encoder.summary()
# Out:
# [INFO] building auto encoder...
# Model: "auto_encoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 256, 256, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 128, 128, 128)  │         3,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_2 (LeakyReLU)       │ (None, 128, 128, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ enc_filter_128                  │ (None, 128, 128, 128)  │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 2097152)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ encoded (Dense)                 │ (None, 48)             │   100,663,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 2097152)        │   102,760,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_1 (Reshape)             │ (None, 128, 128, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_2              │ (None, 256, 256, 128)  │       147,584 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_3 (LeakyReLU)       │ (None, 256, 256, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dec_filter_128                  │ (None, 256, 256, 128)  │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_3              │ (None, 256, 256, 3)    │         3,459 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ decoded (Activation)            │ (None, 256, 256, 3)    │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 203,579,443 (776.59 MB)
#  Trainable params: 203,578,931 (776.59 MB)
#  Non-trainable params: 512 (2.00 KB)

# %%
# train the convolutional auto encoder
print("[INFO] training auto encoder...")
H = auto_encoder.fit(
    train_x, train_x,
    shuffle=True,
    validation_data=(val_x, val_x),
    epochs=EPOCHS,
    callbacks = [checkpoint_callback],
    batch_size=16)
# Out:
# [INFO] training auto encoder...
# Epoch 1/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - loss: 0.0647
# Epoch 1: val_loss improved from None to 0.01440, saving model to training_1_40_subclass/cp.ckpt.weights.h5
#
# Epoch 1: finished saving model to training_1_40_subclass/cp.ckpt.weights.h5
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 82s 611ms/step - loss: 0.0382 - val_loss: 0.0144
# Epoch 2/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - loss: 0.0115
# Epoch 2: val_loss did not improve from 0.01440
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 21s 209ms/step - loss: 0.0112 - val_loss: 0.0216
# Epoch 3/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - loss: 0.0106
# Epoch 3: val_loss did not improve from 0.01440
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 22s 214ms/step - loss: 0.0106 - val_loss: 0.0244
# Epoch 4/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - loss: 0.0101
# Epoch 4: val_loss did not improve from 0.01440
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - loss: 0.0104 - val_loss: 0.0203
# Epoch 5/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - loss: 0.0105
# Epoch 5: val_loss did not improve from 0.01440
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 22s 216ms/step - loss: 0.0103 - val_loss: 0.0172
# Epoch 6/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - loss: 0.0098
# Epoch 6: val_loss improved from 0.01440 to 0.01043, saving model to training_1_40_subclass/cp.ckpt.weights.h5
#
# Epoch 6: finished saving model to training_1_40_subclass/cp.ckpt.weights.h5
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 83s 816ms/step - loss: 0.0102 - val_loss: 0.0104
# Epoch 7/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - loss: 0.0099
# Epoch 7: val_loss improved from 0.01043 to 0.00965, saving model to training_1_40_subclass/cp.ckpt.weights.h5
#
# Epoch 7: finished saving model to training_1_40_subclass/cp.ckpt.weights.h5
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 144s 1s/step - loss: 0.0101 - val_loss: 0.0096
# Epoch 8/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - loss: 0.0098
# Epoch 8: val_loss improved from 0.00965 to 0.00951, saving model to training_1_40_subclass/cp.ckpt.weights.h5
#
# Epoch 8: finished saving model to training_1_40_subclass/cp.ckpt.weights.h5
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - loss: 0.0100 - val_loss: 0.0095
# Epoch 9/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - loss: 0.0099
# Epoch 9: val_loss did not improve from 0.00951
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 23s 224ms/step - loss: 0.0099 - val_loss: 0.0115
# Epoch 10/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - loss: 0.0101
# Epoch 10: val_loss did not improve from 0.00951
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 23s 229ms/step - loss: 0.0099 - val_loss: 0.0126
# Epoch 11/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - loss: 0.0097
# Epoch 11: val_loss did not improve from 0.00951
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 22s 215ms/step - loss: 0.0097 - val_loss: 0.0099
# Epoch 12/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - loss: 0.0097
# Epoch 12: val_loss improved from 0.00951 to 0.00920, saving model to training_1_40_subclass/cp.ckpt.weights.h5
#
# Epoch 12: finished saving model to training_1_40_subclass/cp.ckpt.weights.h5
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 109s 1s/step - loss: 0.0097 - val_loss: 0.0092
# Epoch 13/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - loss: 0.0095
# Epoch 13: val_loss did not improve from 0.00920
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 23s 229ms/step - loss: 0.0096 - val_loss: 0.0148
# Epoch 14/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - loss: 0.0094
# Epoch 14: val_loss improved from 0.00920 to 0.00913, saving model to training_1_40_subclass/cp.ckpt.weights.h5
#
# Epoch 14: finished saving model to training_1_40_subclass/cp.ckpt.weights.h5
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 122s 1s/step - loss: 0.0096 - val_loss: 0.0091
# Epoch 15/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - loss: 0.0095
# Epoch 15: val_loss did not improve from 0.00913
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - loss: 0.0095 - val_loss: 0.0099
# Epoch 16/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - loss: 0.0093
# Epoch 16: val_loss did not improve from 0.00913
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 24s 235ms/step - loss: 0.0094 - val_loss: 0.0098
# Epoch 17/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - loss: 0.0092
# Epoch 17: val_loss did not improve from 0.00913
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 22s 216ms/step - loss: 0.0094 - val_loss: 0.0092
# Epoch 18/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - loss: 0.0094
# Epoch 18: val_loss did not improve from 0.00913
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 41s 216ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 19/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - loss: 0.0090
# Epoch 19: val_loss did not improve from 0.00913
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 24s 234ms/step - loss: 0.0093 - val_loss: 0.0099
# Epoch 20/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - loss: 0.0092
# Epoch 20: val_loss did not improve from 0.00913
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 22s 217ms/step - loss: 0.0093 - val_loss: 0.0095
# Epoch 21/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - loss: 0.0090
# Epoch 21: val_loss did not improve from 0.00913
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 22s 214ms/step - loss: 0.0091 - val_loss: 0.0093
# Epoch 22/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - loss: 0.0089
# Epoch 22: val_loss improved from 0.00913 to 0.00910, saving model to training_1_40_subclass/cp.ckpt.weights.h5
#
# Epoch 22: finished saving model to training_1_40_subclass/cp.ckpt.weights.h5
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 90s 885ms/step - loss: 0.0089 - val_loss: 0.0091
# Epoch 23/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - loss: 0.0085
# Epoch 23: val_loss did not improve from 0.00910
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 24s 235ms/step - loss: 0.0088 - val_loss: 0.0093
# Epoch 24/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - loss: 0.0087
# Epoch 24: val_loss did not improve from 0.00910
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 40s 224ms/step - loss: 0.0087 - val_loss: 0.0092
# Epoch 25/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - loss: 0.0087
# Epoch 25: val_loss did not improve from 0.00910
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 23s 228ms/step - loss: 0.0087 - val_loss: 0.0109
# Epoch 26/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - loss: 0.0086
# Epoch 26: val_loss did not improve from 0.00910
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - loss: 0.0086 - val_loss: 0.0095
# Epoch 27/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - loss: 0.0086
# Epoch 27: val_loss did not improve from 0.00910
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 22s 215ms/step - loss: 0.0085 - val_loss: 0.0093
# Epoch 28/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - loss: 0.0080
# Epoch 28: val_loss did not improve from 0.00910
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - loss: 0.0083 - val_loss: 0.0097
# Epoch 29/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - loss: 0.0081
# Epoch 29: val_loss did not improve from 0.00910
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - loss: 0.0081 - val_loss: 0.0093
# Epoch 30/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - loss: 0.0077
# Epoch 30: val_loss did not improve from 0.00910
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 22s 214ms/step - loss: 0.0079 - val_loss: 0.0098
# Epoch 31/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - loss: 0.0076
# Epoch 31: val_loss did not improve from 0.00910
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 22s 215ms/step - loss: 0.0078 - val_loss: 0.0095
# Epoch 32/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - loss: 0.0075
# Epoch 32: val_loss did not improve from 0.00910
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 23s 223ms/step - loss: 0.0076 - val_loss: 0.0095
# Epoch 33/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - loss: 0.0076
# Epoch 33: val_loss did not improve from 0.00910
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 22s 215ms/step - loss: 0.0076 - val_loss: 0.0102
# Epoch 34/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - loss: 0.0074
# Epoch 34: val_loss did not improve from 0.00910
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 22s 215ms/step - loss: 0.0075 - val_loss: 0.0108
# Epoch 35/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - loss: 0.0073
# Epoch 35: val_loss did not improve from 0.00910
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 22s 214ms/step - loss: 0.0072 - val_loss: 0.0104
# Epoch 36/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - loss: 0.0069
# Epoch 36: val_loss did not improve from 0.00910
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 22s 215ms/step - loss: 0.0070 - val_loss: 0.0105
# Epoch 37/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - loss: 0.0067
# Epoch 37: val_loss did not improve from 0.00910
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 22s 215ms/step - loss: 0.0069 - val_loss: 0.0108
# Epoch 38/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - loss: 0.0067
# Epoch 38: val_loss did not improve from 0.00910
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 22s 216ms/step - loss: 0.0067 - val_loss: 0.0101
# Epoch 39/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - loss: 0.0063
# Epoch 39: val_loss did not improve from 0.00910
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 22s 217ms/step - loss: 0.0064 - val_loss: 0.0100
# Epoch 40/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - loss: 0.0061
# Epoch 40: val_loss did not improve from 0.00910
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 22s 217ms/step - loss: 0.0062 - val_loss: 0.0114
# Epoch 41/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - loss: 0.0060
# Epoch 41: val_loss did not improve from 0.00910
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 22s 217ms/step - loss: 0.0062 - val_loss: 0.0099
# Epoch 42/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - loss: 0.0060
# Epoch 42: val_loss did not improve from 0.00910
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 22s 215ms/step - loss: 0.0061 - val_loss: 0.0108
# Epoch 43/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - loss: 0.0058
# Epoch 43: val_loss did not improve from 0.00910
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 22s 216ms/step - loss: 0.0059 - val_loss: 0.0119
# Epoch 44/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - loss: 0.0057
# Epoch 44: val_loss did not improve from 0.00910
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 22s 216ms/step - loss: 0.0057 - val_loss: 0.0150
# Epoch 45/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - loss: 0.0054
# Epoch 45: val_loss did not improve from 0.00910
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 22s 215ms/step - loss: 0.0055 - val_loss: 0.0102
# Epoch 46/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - loss: 0.0050
# Epoch 46: val_loss did not improve from 0.00910
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 41s 216ms/step - loss: 0.0052 - val_loss: 0.0129
# Epoch 47/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - loss: 0.0050
# Epoch 47: val_loss did not improve from 0.00910
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 42s 226ms/step - loss: 0.0051 - val_loss: 0.0101
# Epoch 48/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - loss: 0.0048
# Epoch 48: val_loss did not improve from 0.00910
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - loss: 0.0050 - val_loss: 0.0108
# Epoch 49/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - loss: 0.0051
# Epoch 49: val_loss did not improve from 0.00910
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 21s 210ms/step - loss: 0.0050 - val_loss: 0.0112
# Epoch 50/50
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - loss: 0.0050
# Epoch 50: val_loss did not improve from 0.00910
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 22s 213ms/step - loss: 0.0049 - val_loss: 0.0288

# %%
print("[INFO] making predictions...")
decoded = auto_encoder.predict(val_x)
vis = visualize_predictions(decoded, val_x)
image_example_path = "reconstruction"
cv2.imwrite(os.path.join(image_example_path,"recon_vis_40_subclass.png"), vis)
N = np.arange(0, EPOCHS)
plt.figure(figsize=(15,7))
plt.plot(N, H.history["loss"], label="train_loss")
plt.plot(N, H.history["val_loss"], label="val_loss")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.show()
# Out:
# [INFO] making predictions...
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 12s 200ms/step

# %%
with open('training_1_40_subclass.json', 'w') as f:
    json.dump(H.history, f)

# %%
auto_encoder.save('training_1_40_subclass.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
